# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")
# Out:
# You are logged on as Ayushi.Sharma_AgriLifePDI with an administrator role, proceed with caution.

# %%
try:
    import psycopg
except ImportError:
    # %pip install psycopg[binary] sqlalchemy pandas

# %% [markdown]
# #### Now you are ready to start!

# %%
from sqlalchemy import create_engine 
import pandas as pd

# %%
DB_DSN = "postgresql+psycopg://hemp_user:hemp_pass@2.tcp.ngrok.io:12329/hemp_db" 
engine = create_engine(DB_DSN)

# %%
query = "SELECT * FROM ofda_runs LIMIT 50;"
df = pd.read_sql(query, engine)
df
# Out:
#     ofda_run_id        sample_id        run_label  run_day   mode  mean_d_um  \
# 0          1191       Hemp_Cf_01       Hemp_Cf_01        5  slide  10.940000
# 1          1192       Hemp_Cf_02       Hemp_Cf_02        5  slide  11.000000
# 2          1193       Hemp_Cf_03       Hemp_Cf_03        5  slide  11.350000
# 3          1194       Hemp_Cf_04       Hemp_Cf_04        5  slide  11.120000
# 4          1195       Hemp_Cf_05       Hemp_Cf_05        5  slide  11.130000
# 5          1196       Hemp_Cf_06       Hemp_Cf_06        5  slide  11.050000
# 6          1198     Hemp_D_Cf_01     Hemp_D_Cf_01        5  slide  11.990000
# 7          1199     Hemp_D_Cf_02     Hemp_D_Cf_02        5  slide  12.320000
# 8          1200     Hemp_D_Cf_03     Hemp_D_Cf_03        5  slide  12.200000
# 9          1201     Hemp_D_Cf_04     Hemp_D_Cf_04        5  slide  12.380000
# 10         1202     Hemp_D_Cf_05     Hemp_D_Cf_05        5  slide  12.270000
# ...

# %%
csv_path = "ofda_runs_subset_v3.csv"
df.to_csv(csv_path, index=False)

table_item = gis.content.add(
    {
        "title": "Hemp OFDA Runs (CSV Upload Only v2)",
        "tags": "hemp, postgres, data upload",
        "description": "Uploaded from PostgreSQL ingest notebook. Second version.",
        "type": "CSV"
    },
    data=csv_path
)

print("✅ Uploaded CSV as item:", table_item)
# Out:
# C:\ArcGIS_Server\Server\framework\runtime\ArcGIS\bin\Python\envs\arcgispro-py3\Lib\site-packages\IPython\core\interactiveshell.py:3550: DeprecatedWarning: add is deprecated as of 2.3.0 and has been removed in 3.0.0. Use `Folder.add()` instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\ArcGIS_Server\Server\framework\runtime\ArcGIS\bin\Python\envs\arcgispro-py3\Lib\site-packages\urllib3\connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'dev-pdi.agnet.tamu.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ✅ Uploaded CSV as item: <Item title:"Hemp OFDA Runs (CSV Upload Only v2)" type:CSV owner:Ayushi.Sharma_AgriLifePDI>
